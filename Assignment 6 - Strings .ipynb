# %% [markdown]
# # Assignment 6 - Strings

# %% [markdown]
# #### Question-1

# %% [markdown]
# <aside>
# 💡 **Question 1**
#
# A permutation perm of n + 1 integers of all the integers in the range [0, n] can be represented as a string s of length n where:
#
# - s[i] == 'I' if perm[i] < perm[i + 1], and
# - s[i] == 'D' if perm[i] > perm[i + 1].
#
# Given a string s, reconstruct the permutation perm and return it. If there are multiple valid permutations perm, return **any of them**.
#
# **Example 1:**
#
# **Input:** s = "IDID"
#
# **Output:**
#
# [0,4,1,3,2]
#
# </aside>

# %%
s = input("Enter the string: ")
print('String is:',s)

def findPermutation(s):
    perm = []
    n = len(s)
    start, end = 0, n

    for ch in s:
        if ch == 'I':
            perm.append(start)
            start += 1
        else:
            perm.append(end)
            end -= 1

    perm.append(start)  # or perm.append(end)

    return perm

result = findPermutation(s)
print(result)
# Out:
# Enter the string:  IDID
# String is: IDID
# [0, 4, 1, 3, 2]

# %% [markdown]
# #### Questiton-2

# %% [markdown]
# <aside>
# 💡 **Question 2**
#
# You are given an m x n integer matrix matrix with the following two properties:
#
# - Each row is sorted in non-decreasing order.
# - The first integer of each row is greater than the last integer of the previous row.
#
# Given an integer target, return true *if* target *is in* matrix *or* false *otherwise*.
#
# You must write a solution in O(log(m * n)) time complexity.
#
# **Example 1:**
# **Input:** matrix = [[1,3,5,7],[10,11,16,20],[23,30,34,60]], target = 3
#
# **Output:** true
# </aside>

# %%
matrix = [
    [1, 3, 5, 7],
    [10, 11, 16, 20],
    [23, 30, 34, 60]
]
target = 3
print('MAtrix is:',matrix)
print('Target-->',target)
def searchMatrix(matrix, target):
    m, n = len(matrix), len(matrix[0])
    left, right = 0, m * n - 1

    while left <= right:
        mid = (left + right) // 2
        row = mid // n
        col = mid % n

        if matrix[row][col] == target:
            return True
        elif matrix[row][col] < target:
            left = mid + 1
        else:
            right = mid - 1

    return False

print(searchMatrix(matrix, target))
# Out:
# MAtrix is: [[1, 3, 5, 7], [10, 11, 16, 20], [23, 30, 34, 60]]
# Target--> 3
# True

# %% [markdown]
# #### Question-3

# %% [markdown]
# <aside>
# 💡 **Question 3**
#
# Given an array of integers arr, return *true if and only if it is a valid mountain array*.
#
# Recall that arr is a mountain array if and only if:
#
# - arr.length >= 3
# - There exists some i with 0 < i < arr.length - 1 such that:
#     - arr[0] < arr[1] < ... < arr[i - 1] < arr[i]
#     - arr[i] > arr[i + 1] > ... > arr[arr.length - 1]
#
# **Example 1:**
# ![image.png](attachment:a05a80b2-94e3-49c9-a814-055616840912.png)
#
# **Input:** arr = [2,1]
#
# **Output:**
#
# false
# </aside>

# %%
arr = [2, 1]
print('Input :',arr)
def validMountainArray(arr):
    n = len(arr)
    
    if n < 3:
        return False
    
    peak = 0
    
    for i in range(1, n):
        if arr[i] == arr[i-1] or arr[i] < arr[i-1]:
            return False
        if arr[i] > arr[i-1]:
            peak = i
    
    if peak == 0 or peak == n - 1:
        return False
    
    for i in range(peak+1, n):
        if arr[i] >= arr[i+1]:
            return False
    
    return True

print(validMountainArray(arr))
# Out:
# Input : [2, 1]
# False

# %% [markdown]
# #### Question-4

# %% [markdown]
# <aside>
# 💡 **Question 4**
#
# Given a binary array nums, return *the maximum length of a contiguous subarray with an equal number of* 0 *and* 1.
#
# **Example 1:**
#
# **Input:** nums = [0,1]
#
# **Output:** 2
#
# **Explanation:**
#
# [0, 1] is the longest contiguous subarray with an equal number of 0 and 1.
#
# </aside>

# %%
n = int(input('Enter the length of the binary array: '))
nums = []

for i in range(n):
    nums.append(int(input(f'Enter the binary element at index {i}: ')))

print(f'Binary Array is: {nums}')


def findMaxLength(nums):
    max_length = 0
    count = 0
    sum_map = {0: -1}

    for i in range(len(nums)):
        if nums[i] == 0:
            count -= 1
        else:
            count += 1

        if count in sum_map:
            max_length = max(max_length, i - sum_map[count])
        else:
            sum_map[count] = i

    return max_length


max_len = findMaxLength(nums)
print(f'Maximum length of a contiguous subarray with an equal number of 0s and 1s: {max_len}')
# Out:
# Enter the length of the binary array:  2
# Enter the binary element at index 0:  0
# Enter the binary element at index 1:  1
# Binary Array is: [0, 1]
# Maximum length of a contiguous subarray with an equal number of 0s and 1s: 2

# %% [markdown]
# #### Question-5

# %% [markdown]
# <aside>
# 💡 **Question 5**
#
# The **product sum** of two equal-length arrays a and b is equal to the sum of a[i] * b[i] for all 0 <= i < a.length (**0-indexed**).
#
# - For example, if a = [1,2,3,4] and b = [5,2,3,1], the **product sum** would be 1*5 + 2*2 + 3*3 + 4*1 = 22.
#
# Given two arrays nums1 and nums2 of length n, return *the **minimum product sum** if you are allowed to **rearrange** the **order** of the elements in* nums1.
#
# **Example 1:**
#
# **Input:** nums1 = [5,3,4,2], nums2 = [4,2,2,5]
#
# **Output:** 40
#
# **Explanation:**
#
# We can rearrange nums1 to become [3,5,4,2]. The product sum of [3,5,4,2] and [4,2,2,5] is 3*4 + 5*2 + 4*2 + 2*5 = 40.
#
# </aside>

# %%
n1 = int(input('Enter the length of the binary array: '))
nums1 = []
for i in range(n1):
    nums1.append(int(input(f'Enter the binary element at index {i}: ')))

n2 = int(input('Enter the length of the binary array: '))
nums2 = []
for i in range(n2):
    nums2.append(int(input(f'Enter the binary element at index {i}: ')))
print(f'Array-1 is: {nums1}')
print(f'Array-2 is: {nums2}')

def minProductSum(nums1, nums2):
    nums1.sort()
    nums2.sort(reverse=True)
    
    min_product_sum = 0
    for i in range(len(nums1)):
        min_product_sum += nums1[i] * nums2[i]
    
    return min_product_sum

min_product = minProductSum(nums1, nums2)
print(min_product)
# Out:
# Enter the length of the binary array:  4
# Enter the binary element at index 0:  5
# Enter the binary element at index 1:  4
# Enter the binary element at index 2:  3
# Enter the binary element at index 3:  2
# Enter the length of the binary array:  4
# Enter the binary element at index 0:  4
# Enter the binary element at index 1:  2
# Enter the binary element at index 2:  2
# Enter the binary element at index 3:  5
# Array-1 is: [5, 4, 3, 2]
# Array-2 is: [4, 2, 2, 5]
# 40

# %% [markdown]
# #### Question-6

# %% [markdown]
# <aside>
# 💡 **Question 6**
#
# An integer array original is transformed into a **doubled** array changed by appending **twice the value** of every element in original, and then randomly **shuffling** the resulting array.
#
# Given an array changed, return original *if* changed *is a **doubled** array. If* changed *is not a **doubled** array, return an empty array. The elements in* original *may be returned in **any** order*.
#
# **Example 1:**
#
# **Input:** changed = [1,3,4,2,6,8]
#
# **Output:** [1,3,4]
#
# **Explanation:** One possible original array could be [1,3,4]:
#
# - Twice the value of 1 is 1 * 2 = 2.
# - Twice the value of 3 is 3 * 2 = 6.
# - Twice the value of 4 is 4 * 2 = 8.
#
# Other original arrays could be [4,3,1] or [3,1,4].
#
# </aside>

# %%
changed = [1, 3, 4, 2, 6, 8]

def findOriginalArray(changed):
    counts = {}
    for num in changed:
        if num in counts:
            counts[num] += 1
        else:
            counts[num] = 1

    original = []
    for num in changed:
        if counts[num] == 0:
            continue
        if num / 2 not in counts or counts[num / 2] == 0:
            return []
        original.append(num // 2)
        counts[num] -= 1
        counts[num // 2] -= 1

    return original

original = findOriginalArray(changed)
print(original)
# Out:
# []

# %% [markdown]
# #### Question-7

# %% [markdown]
# <aside>
# 💡 **Question 7**
#
# Given a positive integer n, generate an n x n matrix filled with elements from 1 to n2 in spiral order.
#
# **Example 1:**
#  ![image.png](attachment:5495046a-ff74-4acd-8c98-2783ded92ae5.png)
#
# **Output:** [[1,2,3],[8,9,4],[7,6,5]]
# </aside>

# %%
n= int(input('Enter length of Mtrx:'))
print('Matrix length is :',n)

def generateMatrix(n):
    matrix = [[0] * n for _ in range(n)]
    num = 1
    row_start, row_end = 0, n - 1
    col_start, col_end = 0, n - 1
    
    while num <= n * n:
        # Traverse top row
        for col in range(col_start, col_end + 1):
            matrix[row_start][col] = num
            num += 1
        row_start += 1
        
        # Traverse right column
        for row in range(row_start, row_end + 1):
            matrix[row][col_end] = num
            num += 1
        col_end -= 1
        
        # Traverse bottom row
        for col in range(col_end, col_start - 1, -1):
            matrix[row_end][col] = num
            num += 1
        row_end -= 1
        
        # Traverse left column
        for row in range(row_end, row_start - 1, -1):
            matrix[row][col_start] = num
            num += 1
        col_start += 1
    
    return matrix

spiral_matrix = generateMatrix(n)
for row in spiral_matrix:
    print(row)
# Out:
# Enter length of Mtrx: 3
# Matrix length is : 3
# [1, 2, 3]
# [8, 9, 4]
# [7, 6, 5]

# %% [markdown]
# ### Question-8

# %% [markdown]
# <aside>
# 💡 **Question 8**
#
# Given two [sparse matrices](https://en.wikipedia.org/wiki/Sparse_matrix) mat1 of size m x k and mat2 of size k x n, return the result of mat1 x mat2. You may assume that multiplication is always possible.
#
# **Example 1:**
#
# ![image.png](attachment:4373e351-5eea-4019-9537-43bdd0119b81.png)
#
# **Input:** mat1 = [[1,0,0],[-1,0,3]], mat2 = [[7,0,0],[0,0,0],[0,0,1]]
#
# **Output:**
#
# [[7,0,0],[-7,0,3]]
# </aside>

# %%
mat1 = [[1, 0, 0], [-1, 0, 3]]
mat2 = [[7, 0, 0], [0, 0, 0], [0, 0, 1]]

def multiplySparseMatrices(mat1, mat2):
    m = len(mat1)
    k = len(mat1[0])
    n = len(mat2[0])

    result = [[0] * n for _ in range(m)]
    sparse_mat1 = {}

    for i in range(m):
        for j in range(k):
            if mat1[i][j] != 0:
                sparse_mat1[(i, j)] = mat1[i][j]

    for i in range(m):
        for j in range(n):
            for k in range(k):
                if mat2[k][j] != 0 and (k, j) in sparse_mat1:
                    result[i][j] += sparse_mat1[(k, j)] * mat2[k][j]

    return result

print('*** MATRIX - 1 ***')
for row in mat1:
    print(row)
print('\n')
print('*** MATRIX - 2 ***')
for row in mat2:
    print(row)

print('\n')
print('***-----> MATRIX <-----***')
result = multiplySparseMatrices(mat1, mat2)
for row in result:
    print("          " + ' '.join(map(str, row)))
# Out:
# *** MATRIX - 1 ***
# [1, 0, 0]
# [-1, 0, 3]
#
#
# *** MATRIX - 2 ***
# [7, 0, 0]
# [0, 0, 0]
# [0, 0, 1]
#
#
# ***-----> MATRIX <-----***
#           7 0 0
#           0 0 0
